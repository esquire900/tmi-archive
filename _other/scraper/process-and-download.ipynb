# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_json('./articles-selenium.json')
engine = create_engine('postgres://postgres:352s7wevz9f@localhost/tmi_archive', echo=False)

# %%
df[['url', 'title', 'audio_link']].to_excel('./articles.xlsx')

# %%
from bs4 import BeautifulSoup
BeautifulSoup(df[pd.isna(df.audio_link)].article.iloc[0]).text
# Out:
# '\n\n\n\t\t\tQ&A: Amount of Concentration Needed for Enlightenment        \n\n\n\n Exactly how much concentration is needed to attain enlightenment?\nStable one-pointedness in the degree corresponding to what is known as ‘Access Samadhi’ to some and ‘Jhana Light’ to others. Other aliases this\xa0samadhi\xa0is known by\xa0include ‘samatha’, ‘the first proximate stabilization of calm abiding’ and ‘shi-neh’.\n Is jhana heavy absolutely necessary?\nCultivation of ‘jhana heavy’ is totally unnecessary for achieving the first stage of Enlightenment, Sotapanna, although it will spontaeously occur\xa0at the time of\xa0attainment. It becomes prevalent in the stage of Sakadagami and onward, developing naturally\xa0and easily.\nIs dry insight sufficient?\nTrick question. If you examine so-called ‘dry insight’, it is a method\xa0that involves achieving the level of\xa0samadhi identified as ‘access’ or ‘jhana light’ above, but without strictly limiting oneself to using a fixed object during the pr
# ...

# %%
df
# Out:
#                                                article  \
# 0    <article class="post-118 post type-post status...
# 1    <article class="post-156 post type-post status...
# 2    <article class="post-363 post type-post status...
# 3    <article class="post-387 post type-post status...
# 4    <article class="post-398 post type-post status...
# ..                                                 ...
# 706  <article class="post-135 post type-post status...
# 707  <article class="post-34 post type-post status-...
# 708  <article class="post-552 post type-post status...
# 709  <article class="post-3710 post type-post statu...
# 710  <article class="post-3733 post type-post statu...
#
#                                                    url  \
# 0    https://dharmatreasure.org/qa-amount-of-concen...
# 1    https://dharmatreasure.org/practice-in-ones-da...
# 2    https://dharmatreasure.org/how-to-deal-with-wr...
# 3    https://dharmatreasure.org/analytical-meditati...
# ...

# %%
df[['title', 'content']].iloc[:2].values
# Out:
# array([['Q&A: Amount of Concentration Needed for Enlightenment',
# ...

# %%
pd.read_sql('select * from talks_talk', engine)
# Out:
#    id title description                                 audio_original  \
# 0   2  Test   test talk  audio/original/EXFZP6YFLBE2LNKRT5DCLY73E4.mp3
#
#   audio_cleaned                       created_at  \
# 0               2020-09-19 10:05:13.270382+00:00
#
#                         updated_at  created_by_id  updated_by_id
# 0 2020-09-19 10:49:44.327132+00:00              1              1

# %%
import os
# download
def download_file(url, folder='./mp3/'):
    local_filename = folder+url.split('/')[-1].replace('?_=1', '')
    if os.path.exists(local_filename):
        return True
    # NOTE the stream=True parameter below
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192): 
                # If you have chunk encoded response uncomment if
                # and set chunk_size parameter to None.
                #if chunk: 
                f.write(chunk)
    return local_filename

# %%
import requests
for l in df.audio_link.values:
    if l is not None:
        try:
            download_file(l)
        except Exception:
            print(l)
            continue
